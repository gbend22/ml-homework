# %%
import numpy as np
import pandas as pd
import os
for dirname, _, filenames in os.walk('C:/Users/Acer/Desktop/ml-homework/Data/'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# C:/Users/Acer/Desktop/ml-homework/Data/data_description.txt
# C:/Users/Acer/Desktop/ml-homework/Data/sample_submission.csv
# C:/Users/Acer/Desktop/ml-homework/Data/test.csv
# C:/Users/Acer/Desktop/ml-homework/Data/train.csv

# %%
import pandas as pd

df = pd.read_csv('C:/Users/Acer/Desktop/ml-homework/Data/test.csv')

# %%
import mlflow
logged_model = 'runs:/82988b9f799540b5ac28ccedf728856b/linear_regression_model'

# Load model as a PyFuncModel.
loaded_model = mlflow.pyfunc.load_model(logged_model)
# Out:
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# Cell In[9], line 5
#       2 logged_model = 'runs:/82988b9f799540b5ac28ccedf728856b/linear_regression_model'
#       4 # Load model as a PyFuncModel.
# ----> 5 loaded_model = mlflow.pyfunc.load_model(logged_model)
#
# File c:\Users\Acer\AppData\Local\Programs\Python\Python311\Lib\site-packages\mlflow\tracing\provider.py:422, in trace_disabled.<locals>.wrapper(*args, **kwargs)
#     420 disable()
#     421 try:
# --> 422     is_func_called, result = True, f(*args, **kwargs)
#     423 finally:
#     424     enable()
#
# File c:\Users\Acer\AppData\Local\Programs\Python\Python311\Lib\site-packages\mlflow\pyfunc\__init__.py:1091, in load_model(model_uri, suppress_warnings, dst_path, model_config)
#    1087         entity_list.append(Entity(job=job_entity))
# ...

# %%
import mlflow
import pandas as pd
logged_model = 'runs:/34755db6ae704dc89a3ab07c912e9f33/pipeline'

# Load model as a PyFuncModel.
loaded_model = mlflow.sklearn.load_model(logged_model)
# Out:
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# Cell In[15], line 6
#       3 logged_model = 'runs:/34755db6ae704dc89a3ab07c912e9f33/pipeline'
#       5 # Load model as a PyFuncModel.
# ----> 6 loaded_model = mlflow.sklearn.load_model(logged_model)
#
# File c:\Users\Acer\AppData\Local\Programs\Python\Python311\Lib\site-packages\mlflow\sklearn\__init__.py:633, in load_model(model_uri, dst_path)
#     598 def load_model(model_uri, dst_path=None):
#     599     """
#     600     Load a scikit-learn model from a local file or a run.
#     601
#    (...)    631         predictions = sk_model.predict(pandas_df)
#     632     """
# --> 633     local_model_path = _download_artifact_from_uri(artifact_uri=model_uri, output_path=dst_path)
#     634     flavor_conf = _get_flavor_configuration(model_path=local_model_path, flavor_name=FLAVOR_NAME)
# ...
